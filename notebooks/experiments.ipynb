# %%
import pandas as pd
import matplotlib.pyplot as plt
# Load the CSV we just created
data = pd.read_csv('../artifacts/logs/positions.csv')

plt.figure(figsize=(10, 5))
plt.plot(data['x'], data['y'], label='Ball Path')
plt.title('Baseline Ball Trajectory')
plt.invert_yaxis() # Videos have 0,0 at top-left
plt.savefig('../artifacts/plots/readme_trajectory.png')
